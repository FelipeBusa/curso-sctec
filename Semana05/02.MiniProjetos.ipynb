# %% [markdown]
# # MINI PROJETOS - SEMANA 05

# %% [markdown]
# ## MINI PROJETO 1 - Dashboard Comercial
#
# Usar:
# - ✅ read_csv()
# - ✅ merge()
# - ✅ groupby()
# - ✅ sort_values()
# - ✅ value_counts()
# - ✅ describe()
# - ✅ filtros
# - ✅ criação de colunas
# - ✅ lambda
# - ✅ NumPy
#
# O relatório deverá responder:
# - Total vendido
# - Quantidade vendida
# - Ticket médio
# - Top vendedores
# - Top clientes
# - Top produtos
# - Produto menos vendido
# - Cidade que mais compra
# - Categoria mais vendida
# - Preço médio
# - Maior venda
# - Menor venda
# - Dashboard Final

# %%
# Dataset:
clientes.csv
produtos.csv
vendas.csv

# %% [markdown]
# ## MINI PROJETO 2 - RH Inteligente
#
# Usar:
# - merge
# - Excel
# - JSON
# - CSV
# - regex
# - datetime
# - funções
#
# Indicadores:
# - Quantidade funcionários
# - Departamento destaque
# - Cargo destaque
# - Maior salário
# - Menor salário
# - Funcionário mais antigo
# - Funcionário mais novo
# - Horas trabalhadas
# - Horas extras
# - Atrasados
# - Pontuais
# - Muito atrasados
# - Funcionários com e-mail inválido
# - Dashboard RH

# %%
funcionarios.csv
banco_horas.xlsx
emails.json

# %% [markdown]
# ## MINI PROJETO 3 - Estoque Inteligente 2.0
#
# Usar:
# - CSV
# - NumPy
# - Pandas
# - groupby
# - sort
# - describe
# - lambda
# - funções
#
# Indicadores:
# - Valor total estoque
# - Itens em estoque
# - Fornecedor destaque
# - Categoria destaque
# - Produto mais caro
# - Produto mais barato
# - Maior estoque
# - Menor estoque
# - Produtos críticos
# - Curva ABC (introdução)
# - Dashboard
