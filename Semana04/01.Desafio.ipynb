# %% [markdown]
# # EXERCÍCIO 1 - Cadastro de Funcionários
# Arquivo: cadastro_funcionario.csv
#
# Faça:
# * Ler o CSV.
# * Contar funcionários por setor.
# * Contar funcionários por cargo.
# * Descobrir qual setor possui mais funcionários.
# * Descobrir qual cargo possui menos funcionários.
#
# Objetivo - Treinar:
# * CSV
# * lista de dicionários
# * criação de dicionários resumo

# %%
# importar leitor csv
import csv

# abrir e ler arquivo csv
with open("cadastro_funcionario.csv", encoding="utf-8") as arquivo:
    leitor = csv.DictReader(arquivo)
    funcionarios = list(leitor)

# # Print iniciais para mostrar resultados básicos
# print(type(funcionarios))
# print(funcionarios[0])
# print(funcionarios[0].keys())

# =============================
# 1. CADASTRO DE FUNCIONÁRIOS
print("=" * 40)
print("1. CADASTRO DE FUNCIONÁRIOS")
print("=" * 40)

# Quantidade funcionários
print(f"Total de funcionários: {len(funcionarios)}")


# =============================
# 2. CALCULO DE FUNCIONÁRIOS
print("")
print("=" * 40)
print("2. CALCULO DE FUNCIONÁRIOS")
print("=" * 40)

# calculo quantidade funcionários:
setores = {}

for funcionario in funcionarios:
    setor = funcionario["setor"]

    if setor not in setores:
        setores[setor] = 1

    else:
        setores[setor] += 1

for setor, quantidade in setores.items():
    print(f"{setor} ..... {quantidade} funcionário(s)")



# calculo setor com mais e menor funcionários
primeiro_setor = list(setores.keys())[0]

maior_setor = primeiro_setor
menor_setor = primeiro_setor

maior_quantidade = setores[primeiro_setor]
menor_quantidade = setores[primeiro_setor]

for setor, quantidade in setores.items():

    if quantidade > maior_quantidade:
        maior_quantidade = quantidade
        maior_setor = setor

    if quantidade < menor_quantidade:
        menor_quantidade = quantidade
        menor_setor = setor

print()
print(f"Setor com mais funcionários: {maior_setor} ({maior_quantidade})")
print(f"Setor com menos funcionários: {menor_setor} ({menor_quantidade})")


# =============================
# 3. CALCULO CARGO
print("")
print("=" * 40)
print("3. CALCULO CARGO")
print("=" * 40)

# calculo quantidade cargo:
cargos = {}
cargo_destaque = ""

for funcionario in funcionarios:

    cargo = funcionario["cargo"]

    if cargo not in cargos:
        cargos[cargo] = 1

    else:
        cargos[cargo] += 1

for cargo, quantidade in cargos.items():
    print(f"{cargo} ..... {quantidade} funcionário(s)")


# calculando cargo com mais e menos funcionários
primeiro_cargo = list(cargos.keys())[0]
maior_cargo = primeiro_cargo
menor_cargo = primeiro_cargo

maior_quantidade = cargos[primeiro_cargo]
menor_quantidade = cargos[primeiro_cargo]

for cargo, quantidade in cargos.items():

    if quantidade > maior_quantidade:
        maior_quantidade = quantidade
        maior_cargo = cargo

    if quantidade < menor_quantidade:
        menor_quantidade = quantidade
        menor_cargo = cargo


print()
print(f"Cargo com mais funcionários: {maior_cargo} ({maior_quantidade})")
print(f"Cargo com menos funcionários: {menor_cargo} ({menor_quantidade})")
# Out:
# ========================================
# 1. CADASTRO DE FUNCIONÁRIOS
# ========================================
# Total de funcionários: 30
#
# ========================================
# 2. CALCULO DE FUNCIONÁRIOS
# ========================================
# Comercial ..... 8 funcionário(s)
# Logística ..... 10 funcionário(s)
# Estoque ..... 9 funcionário(s)
# RH ..... 3 funcionário(s)
#
# Setor com mais funcionários: Logística (10)
# Setor com menos funcionários: RH (3)
#
# ========================================
# 3. CALCULO CARGO
# ========================================
# Atendente ..... 7 funcionário(s)
# Motorista ..... 9 funcionário(s)
# Separador de Estoque ..... 7 funcionário(s)
# Analista de RH ..... 1 funcionário(s)
# Supervisora ..... 3 funcionário(s)
# Auxiliar Adm. ..... 2 funcionário(s)
# Auxiliar de Estoque ..... 1 funcionário(s)
#
# Cargo com mais funcionários: Motorista (9)
# Cargo com menos funcionários: Analista de RH (1)

# %% [markdown]
# # EXERCÍCIO 2 - Cadastro de E-mails
# Arquivo: emails_corporativos.json
#
# Faça:
# * Ler o JSON.
# * Validar todos os e-mails.
# * Contar válidos.
# * Contar inválidos.
# * Mostrar somente os inválidos.
# * Depois crie:
#     * def validar_email(email):
#     * e utilize a função.
#
# Objetivo - Treinar:
# * JSON
# * funções
# * regex

# %%
import json
import re

with open("emails_corporativos.json", encoding="utf-8") as arquivo:
    emails = json.load(arquivo)

# print(emails[0])


# =================================
# Quantidade de e-mails validos e invalidos
print("")
print("=" * 40)
print("1. QUANTIDADE E-MAILS VÁLIDOS E INVALIDOS")
print("=" * 40)

padrao = r"^[^\s@]+@[^\s@]+\.[^\s@]+$"
email_validos = 0
email_invalido = 0


for email in emails:
    email = email['email']

    if re.match(padrao, email):
        email_validos += 1
    else:
        email_invalido += 1
print(f"Quantidade E-mails Validos ..... {email_validos} e-mails")
print(f"Quantidade E-mails Invalido ..... {email_invalido} e-mails\n")


# =============================
# LISTA E-MAILS INVALIDOS
print("")
print("=" * 40)
print("2. LISTA E-MAILS INVALIDOS")
print("=" * 40)

# Lista E-mails Invalidos
padrao = r"^[^\s@]+@[^\s@]+\.[^\s@]+$"
email_validos = 0
email_invalido = 0

for email in emails:
    email = email['email']

    if re.match(padrao, email):
        email_validos += 1
    else:
        email_invalido += 1
        print(email)



# =============================
# DEF validação e-mail
print("")
print("=" * 40)
print("3. VALIDAÇÃO E-MAIL")
print("=" * 40)

def validar_email(email):
    padrao = r"^[^\s@]+@[^\s@]+\.[^\s@]+$"
    if re.match(padrao, email):
        return "E-mail Valido"
    else:
        return "E-mail Invalido"

for email in emails:
    email = email['email']
    print(f"E-mail: {email} - {validar_email(email)}")
# Out:
# ========================================
# 1. QUANTIDADE E-MAILS VÁLIDOS E INVALIDOS
# ========================================
# Quantidade E-mails Validos ..... 25 e-mails
# Quantidade E-mails Invalido ..... 5 e-mails
#
#
# ========================================
# 2. LISTA E-MAILS INVALIDOS
# ========================================
# carlos.mendesgrupoalfa.com.br
# helena martins@grupoalfa.com.br
# paulo.gomes@@grupoalfa.com.br
# vinicius.barbosa@
# andre.batista@grupoalfacombr
#
# ========================================
# 3. VALIDAÇÃO E-MAIL
# ========================================
# E-mail: ana.souza@grupoalfa.com.br - E-mail Valido
# E-mail: bruno.lima@grupoalfa.com.br - E-mail Valido
# E-mail: carlos.mendesgrupoalfa.com.br - E-mail Invalido
# E-mail: daniela.rocha@grupoalfa.com.br - E-mail Valido
# E-mail: eduardo.santos@grupoalfa.com.br - E-mail Valido
# E-mail: fernanda.costa@grupoalfa.com.br - E-mail Valido
# E-mail: gabriel.oliveira@grupoalfa.com.br - E-mail Valido
# E-mail: helena martins@grupoalfa.com.br - E-mail Invalido
# E-mail: igor.pereira@grupoalfa.com.br - E-mail Valido
# E-mail: juliana.neves@grupoalfa.com.br - E-mail Valido
# E-mail: lucas.alves@grupoalfa.com.br - E-mail Valido
# E-mail: mariana.castro@grupoalfa.com.br - E-mail Valido
# E-mail: nathan.ribeiro@grupoalfa.com.br - E-mail Valido
# E-mail: olivia.ferreira@grupoalfa.com.br - E-mail Valido
# E-mail: paulo.gomes@@grupoalfa.com.br - E-mail Invalido
# E-mail: queila.dias@grupoalfa.com.br - E-mail Valido
# E-mail: rafael.teixeira@grupoalfa.com.br - E-mail Valido
# E-mail: sabrina.moura@grupoalfa.com.br - E-mail Valido
# E-mail: thiago.cardoso@grupoalfa.com.br - E-mail Valido
# E-mail: ursula.pinto@grupoalfa.com.br - E-mail Valido
# E-mail: vinicius.barbosa@ - E-mail Invalido
# E-mail: wanderson.cruz@grupoalfa.com.br - E-mail Valido
# E-mail: ximena.lopes@grupoalfa.com.br - E-mail Valido
# E-mail: yago.nascimento@grupoalfa.com.br - E-mail Valido
# E-mail: zilda.campos@grupoalfa.com.br - E-mail Valido
# E-mail: andre.batista@grupoalfacombr - E-mail Invalido
# E-mail: beatriz.cunha@grupoalfa.com.br - E-mail Valido
# E-mail: caio.freitas@grupoalfa.com.br - E-mail Valido
# E-mail: debora.azevedo@grupoalfa.com.br - E-mail Valido
# E-mail: emerson.tavares@grupoalfa.com.br - E-mail Valido

# %% [markdown]
# # EXERCÍCIO 3 - Banco de Horas
# Arquivo: recursos_humanos.xlsx
#
# Faça:
# * Ler o Excel.
# * Mostrar os cinco primeiros registros.
# * Calcular horas trabalhadas.
# * Calcular atraso.
# * Classificar:
#     * Pontual
#     * Atrasado
#     * Muito atrasado
